# %% [markdown]
# ## Markov Chain for Lunch Preferences at Duke

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")

# %%
### data cleaning
col_mapper = {'What is your relationship to Duke?':'affinity', 'Where did you eat lunch today?':'curr', 'Where do you think you will eat lunch tomorrow?':'next'}
df.rename(columns=col_mapper, inplace=True)

# %%
print(df['affinity'].value_counts())
print(df['curr'].value_counts())
print(df['next'].value_counts())
# Out:
# Sophomore           46
# Junior              23
# Senior              22
# Freshmen            13
# Graduate Student     6
# Faculty/Staff        4
# Name: affinity, dtype: int64
# Other                                     16
# Tandoor                                   12
# Ginger and Soy                             9
# Sazon                                      9
# Il Forno                                   8
# Panera                                     6
# Devil's Krafthouse                         6
# Zweli's                                    5
# Farmstead or Sprout                        5
# Thyme                                      4
# Skillet                                    4
# Gothic Grill                               4
# McDonalds                                  4
# JB's Roast and Chops                       4
# Pitchforks                                 4
# Chef's Kitchen (Taste of San Fransico)     3
# Red Mango                                  3
# The Commons                                2
# Twinnie's                                  2
# Marketplace                                2
# Cafe                                       1
# Saladelia at Perkins                       1
# Name: curr, dtype: int64
# Ginger and Soy                            25
# Other                                     11
# Tandoor                                   11
# Il Forno                                   7
# Thyme                                      6
# Sazon                                      6
# Farmstead or Sprout                        6
# Gothic Grill                               5
# Chef's Kitchen (Taste of San Fransico)     5
# JB's Roast and Chops                       5
# Panera                                     5
# McDonalds                                  4
# Marketplace                                4
# Devil's Krafthouse                         3
# Red Mango                                  2
# Twinnie's                                  2
# Zweli's                                    2
# Pitchforks                                 1
# Nasher Cafe                                1
# Skillet                                    1
# Cafe                                       1
# Freeman Center Cafe                        1
# Name: next, dtype: int64

# %%
### create the transition matrix for all affinities

"""
create transition matrix using pd.crosstab function,
fill NaNs with 0s 
"""
# curr_freqs = df['curr'].value_counts(normalize=True)
# next_freqs = df['next'].value_counts(normalize=True)

temp = pd.concat([df['curr'], df['next']], axis=1)
t = pd.crosstab(temp['curr'], temp['next'], normalize='index')
t = t.fillna(0)

print("\nTransition Matrix:")
print(t)
# Out:
# Transition Matrix:
# next                                        Cafe  \
# curr
# Cafe                                    0.000000
# Chef's Kitchen (Taste of San Fransico)  0.000000
# Devil's Krafthouse                      0.000000
# Farmstead or Sprout                     0.000000
# Ginger and Soy                          0.000000
# Gothic Grill                            0.000000
# Il Forno                                0.000000
# JB's Roast and Chops                    0.000000
# Marketplace                             0.000000
# McDonalds                               0.000000
# Other                                   0.000000
# Panera                                  0.166667
# Pitchforks                              0.000000
# Red Mango                               0.000000
# Saladelia at Perkins                    0.000000
# Sazon                                   0.000000
# Skillet                                 0.000000
# Tandoor                                 0.000000
# The Commons                             0.000000
# Thyme                                   0.000000
# Twinnie's                               0.000000
# Zweli's                                 0.000000
#
# next                                    Chef's Kitchen (Taste of San Fransico)  \
# curr
# Cafe                                                                  1.000000
# Chef's Kitchen (Taste of San Fransico)                                0.000000
# Devil's Krafthouse                                                    0.333333
# Farmstead or Sprout                                                   0.000000
# Ginger and Soy                                                        0.111111
# Gothic Grill                                                          0.000000
# Il Forno                                                              0.000000
# JB's Roast and Chops                                                  0.000000
# Marketplace                                                           0.000000
# McDonalds                                                             0.250000
# Other                                                                 0.000000
# Panera                                                                0.000000
# Pitchforks                                                            0.000000
# Red Mango                                                             0.000000
# Saladelia at Perkins                                                  0.000000
# Sazon                                                                 0.000000
# Skillet                                                               0.000000
# Tandoor                                                               0.000000
# The Commons                                                           0.000000
# Thyme                                                                 0.000000
# Twinnie's                                                             0.000000
# Zweli's                                                               0.000000
#
# next                                    Devil's Krafthouse  \
# curr
# Cafe                                                   0.0
# Chef's Kitchen (Taste of San Fransico)                 0.0
# Devil's Krafthouse                                     0.0
# Farmstead or Sprout                                    0.2
# Ginger and Soy                                         0.0
# Gothic Grill                                           0.0
# Il Forno                                               0.0
# JB's Roast and Chops                                   0.0
# Marketplace                                            0.5
# McDonalds                                              0.0
# Other                                                  0.0
# Panera                                                 0.0
# Pitchforks                                             0.0
# Red Mango                                              0.0
# Saladelia at Perkins                                   0.0
# Sazon                                                  0.0
# Skillet                                                0.0
# Tandoor                                                0.0
# The Commons                                            0.0
# Thyme                                                  0.0
# Twinnie's                                              0.0
# Zweli's                                                0.2
#
# next                                    Farmstead or Sprout  \
# curr
# Cafe                                               0.000000
# Chef's Kitchen (Taste of San Fransico)             0.000000
# Devil's Krafthouse                                 0.166667
# Farmstead or Sprout                                0.200000
# Ginger and Soy                                     0.222222
# Gothic Grill                                       0.250000
# Il Forno                                           0.000000
# JB's Roast and Chops                               0.000000
# Marketplace                                        0.000000
# McDonalds                                          0.000000
# Other                                              0.000000
# Panera                                             0.000000
# Pitchforks                                         0.000000
# Red Mango                                          0.000000
# Saladelia at Perkins                               0.000000
# Sazon                                              0.000000
# Skillet                                            0.000000
# Tandoor                                            0.000000
# The Commons                                        0.000000
# Thyme                                              0.250000
# Twinnie's                                          0.000000
# Zweli's                                            0.000000
#
# next                                    Freeman Center Cafe  Ginger and Soy  \
# curr
# Cafe                                                   0.00        0.000000
# Chef's Kitchen (Taste of San Fransico)                 0.00        0.666667
# Devil's Krafthouse                                     0.00        0.166667
# Farmstead or Sprout                                    0.00        0.000000
# Ginger and Soy                                         0.00        0.333333
# Gothic Grill                                           0.00        0.250000
# Il Forno                                               0.00        0.250000
# JB's Roast and Chops                                   0.00        0.500000
# Marketplace                                            0.00        0.000000
# McDonalds                                              0.25        0.000000
# Other                                                  0.00        0.187500
# Panera                                                 0.00        0.166667
# Pitchforks                                             0.00        0.750000
# Red Mango                                              0.00        0.000000
# Saladelia at Perkins                                   0.00        1.000000
# Sazon                                                  0.00        0.222222
# Skillet                                                0.00        0.250000
# Tandoor                                                0.00        0.250000
# The Commons                                            0.00        0.000000
# Thyme                                                  0.00        0.000000
# Twinnie's                                              0.00        0.000000
# Zweli's                                                0.00        0.000000
#
# next                                    Gothic Grill  Il Forno  \
# curr
# Cafe                                        0.000000  0.000000
# Chef's Kitchen (Taste of San Fransico)      0.000000  0.000000
# Devil's Krafthouse                          0.000000  0.000000
# Farmstead or Sprout                         0.200000  0.000000
# Ginger and Soy                              0.111111  0.000000
# Gothic Grill                                0.000000  0.000000
# Il Forno                                    0.000000  0.000000
# JB's Roast and Chops                        0.000000  0.250000
# Marketplace                                 0.000000  0.000000
# McDonalds                                   0.000000  0.250000
# Other                                       0.000000  0.062500
# Panera                                      0.166667  0.000000
# Pitchforks                                  0.000000  0.000000
# Red Mango                                   0.000000  0.000000
# Saladelia at Perkins                        0.000000  0.000000
# Sazon                                       0.000000  0.222222
# Skillet                                     0.000000  0.000000
# Tandoor                                     0.083333  0.166667
# The Commons                                 0.000000  0.000000
# Thyme                                       0.250000  0.000000
# Twinnie's                                   0.000000  0.000000
# Zweli's                                     0.000000  0.000000
#
# next                                    JB's Roast and Chops  Marketplace  \
# curr
# Cafe                                                0.000000     0.000000
# Chef's Kitchen (Taste of San Fransico)              0.000000     0.000000
# Devil's Krafthouse                                  0.000000     0.000000
# Farmstead or Sprout                                 0.200000     0.000000
# Ginger and Soy                                      0.000000     0.000000
# Gothic Grill                                        0.000000     0.000000
# Il Forno                                            0.125000     0.000000
# JB's Roast and Chops                                0.000000     0.000000
# Marketplace                                         0.000000     0.500000
# McDonalds                                           0.000000     0.000000
# Other                                               0.062500     0.000000
# Panera                                              0.000000     0.000000
# Pitchforks                                          0.000000     0.000000
# Red Mango                                           0.000000     0.000000
# Saladelia at Perkins                                0.000000     0.000000
# Sazon                                               0.222222     0.111111
# Skillet                                             0.000000     0.250000
# Tandoor                                             0.000000     0.000000
# The Commons                                         0.000000     0.000000
# Thyme                                               0.000000     0.000000
# Twinnie's                                           0.000000     0.000000
# Zweli's                                             0.000000     0.200000
#
# next                                    ...     Other    Panera  Pitchforks  \
# curr                                    ...
# Cafe                                    ...  0.000000  0.000000      0.0000
# Chef's Kitchen (Taste of San Fransico)  ...  0.000000  0.000000      0.0000
# Devil's Krafthouse                      ...  0.000000  0.333333      0.0000
# Farmstead or Sprout                     ...  0.000000  0.000000      0.0000
# Ginger and Soy                          ...  0.111111  0.000000      0.0000
# Gothic Grill                            ...  0.000000  0.000000      0.0000
# Il Forno                                ...  0.125000  0.000000      0.0000
# JB's Roast and Chops                    ...  0.250000  0.000000      0.0000
# Marketplace                             ...  0.000000  0.000000      0.0000
# McDonalds                               ...  0.000000  0.000000      0.0000
# Other                                   ...  0.312500  0.062500      0.0625
# Panera                                  ...  0.000000  0.166667      0.0000
# Pitchforks                              ...  0.250000  0.000000      0.0000
# Red Mango                               ...  0.333333  0.000000      0.0000
# Saladelia at Perkins                    ...  0.000000  0.000000      0.0000
# Sazon                                   ...  0.000000  0.000000      0.0000
# Skillet                                 ...  0.000000  0.000000      0.0000
# Tandoor                                 ...  0.083333  0.083333      0.0000
# The Commons                             ...  0.000000  0.000000      0.0000
# Thyme                                   ...  0.000000  0.000000      0.0000
# Twinnie's                               ...  0.000000  0.000000      0.0000
# Zweli's                                 ...  0.000000  0.000000      0.0000
#
# next                                    Red Mango     Sazon  Skillet  \
# curr
# Cafe                                         0.00  0.000000     0.00
# Chef's Kitchen (Taste of San Fransico)       0.00  0.333333     0.00
# Devil's Krafthouse                           0.00  0.000000     0.00
# Farmstead or Sprout                          0.00  0.200000     0.00
# Ginger and Soy                               0.00  0.000000     0.00
# Gothic Grill                                 0.25  0.000000     0.00
# Il Forno                                     0.00  0.125000     0.00
# JB's Roast and Chops                         0.00  0.000000     0.00
# Marketplace                                  0.00  0.000000     0.00
# McDonalds                                    0.00  0.000000     0.00
# Other                                        0.00  0.062500     0.00
# Panera                                       0.00  0.000000     0.00
# Pitchforks                                   0.00  0.000000     0.00
# Red Mango                                    0.00  0.333333     0.00
# Saladelia at Perkins                         0.00  0.000000     0.00
# Sazon                                        0.00  0.111111     0.00
# Skillet                                      0.00  0.000000     0.25
# Tandoor                                      0.00  0.000000     0.00
# The Commons                                  0.00  0.000000     0.00
# Thyme                                        0.00  0.000000     0.00
# Twinnie's                                    0.50  0.000000     0.00
# Zweli's                                      0.00  0.000000     0.00
#
# next                                     Tandoor     Thyme  Twinnie's  \
# curr
# Cafe                                    0.000000  0.000000        0.0
# Chef's Kitchen (Taste of San Fransico)  0.000000  0.000000        0.0
# Devil's Krafthouse                      0.000000  0.000000        0.0
# Farmstead or Sprout                     0.000000  0.000000        0.0
# Ginger and Soy                          0.000000  0.000000        0.0
# Gothic Grill                            0.000000  0.250000        0.0
# Il Forno                                0.375000  0.000000        0.0
# JB's Roast and Chops                    0.000000  0.000000        0.0
# Marketplace                             0.000000  0.000000        0.0
# McDonalds                               0.000000  0.000000        0.0
# Other                                   0.062500  0.062500        0.0
# Panera                                  0.166667  0.166667        0.0
# Pitchforks                              0.000000  0.000000        0.0
# Red Mango                               0.000000  0.333333        0.0
# Saladelia at Perkins                    0.000000  0.000000        0.0
# Sazon                                   0.111111  0.000000        0.0
# Skillet                                 0.000000  0.000000        0.0
# Tandoor                                 0.000000  0.166667        0.0
# The Commons                             0.500000  0.000000        0.5
# Thyme                                   0.500000  0.000000        0.0
# Twinnie's                               0.000000  0.000000        0.5
# Zweli's                                 0.400000  0.000000        0.0
#
# next                                     Zweli's
# curr
# Cafe                                    0.000000
# Chef's Kitchen (Taste of San Fransico)  0.000000
# Devil's Krafthouse                      0.000000
# Farmstead or Sprout                     0.000000
# Ginger and Soy                          0.000000
# Gothic Grill                            0.000000
# Il Forno                                0.000000
# JB's Roast and Chops                    0.000000
# Marketplace                             0.000000
# McDonalds                               0.000000
# Other                                   0.000000
# Panera                                  0.000000
# Pitchforks                              0.000000
# Red Mango                               0.000000
# Saladelia at Perkins                    0.000000
# Sazon                                   0.000000
# Skillet                                 0.000000
# Tandoor                                 0.083333
# The Commons                             0.000000
# Thyme                                   0.000000
# Twinnie's                               0.000000
# Zweli's                                 0.200000
#
# [22 rows x 22 columns]

# %%
### save transition matrix as csv
t.to_csv("transition.csv")

# %%
### define functions

def predict_future_lunch(curr_lunch, num_steps, transition_matrix=t):
    # params = today's lunch, x days in the future
    # ret = most likely lunch in x days
    t = transition_matrix**num_steps
    return t.loc[curr_lunch].idxmax()

def find_prob_of_future_lunch(curr_lunch, next_lunch, num_steps, transition_matrix=t):
    # params = today's lunch, next lunch, x days in the future, transition matrix
    # ret = prob of eating at next_lunch in x days 
    t = transition_matrix**num_steps
    curr_index = transition_matrix.index.get_loc(curr_lunch)
    next_index = transition_matrix.columns.get_loc(next_lunch)
    return t.iloc[curr_index, next_index]

# %%
### test functions 

print(predict_future_lunch('Sazon', 1, t))
print(find_prob_of_future_lunch("Tandoor", "Zweli's", 2, t))
# Out:
# Ginger and Soy
# 0.006944444444444444
