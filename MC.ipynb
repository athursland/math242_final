# %% [markdown]
# ## Markov Chain for Lunch Preferences at Duke

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")

# %%
### data cleaning
col_mapper = {'What is your relationship to Duke?':'affinity', 'Where did you eat lunch today?':'curr', 'Where do you think you will eat lunch tomorrow?':'next'}
df.rename(columns=col_mapper, inplace=True)

# %%
print(df['affinity'].value_counts())
print(df['curr'].value_counts())
print(df['next'].value_counts())
# Out:
# Sophomore           41
# Junior              16
# Senior              15
# Freshmen            13
# Graduate Student     5
# Faculty/Staff        2
# Name: affinity, dtype: int64
# Other                                     10
# Tandoor                                    9
# Sazon                                      9
# Il Forno                                   8
# Ginger and Soy                             8
# Zweli's                                    5
# Pitchforks                                 4
# JB's Roast and Chops                       4
# Farmstead or Sprout                        4
# Gothic Grill                               4
# Devil's Krafthouse                         4
# Thyme                                      4
# Chef's Kitchen (Taste of San Fransico)     3
# Panera                                     3
# Skillet                                    3
# Marketplace                                2
# The Commons                                2
# Red Mango                                  2
# Cafe                                       1
# McDonalds                                  1
# Twinnie's                                  1
# Saladelia at Perkins                       1
# Name: curr, dtype: int64
# Ginger and Soy                            21
# Tandoor                                   10
# Other                                      9
# Il Forno                                   7
# Sazon                                      5
# JB's Roast and Chops                       5
# Farmstead or Sprout                        4
# Gothic Grill                               4
# Marketplace                                4
# Thyme                                      4
# Panera                                     4
# Devil's Krafthouse                         3
# Chef's Kitchen (Taste of San Fransico)     3
# Zweli's                                    2
# Red Mango                                  2
# Nasher Cafe                                1
# McDonalds                                  1
# Pitchforks                                 1
# Twinnie's                                  1
# Skillet                                    1
# Name: next, dtype: int64

# %%
### create the transition matrix for all affinities

"""
create transition matrix using pd.crosstab function,
fill NaNs with 0s 
"""
# curr_freqs = df['curr'].value_counts(normalize=True)
# next_freqs = df['next'].value_counts(normalize=True)

temp = pd.concat([df['curr'], df['next']], axis=1)
t = pd.crosstab(temp['curr'], temp['next'], normalize='index')
t = t.fillna(0)

print("\nTransition Matrix:")
print(t)
# Out:
# Transition Matrix:
# next                                    Chef's Kitchen (Taste of San Fransico)  \
# curr
# Cafe                                                                       1.0
# Chef's Kitchen (Taste of San Fransico)                                     0.0
# Devil's Krafthouse                                                         0.5
# Farmstead or Sprout                                                        0.0
# Ginger and Soy                                                             0.0
# Gothic Grill                                                               0.0
# Il Forno                                                                   0.0
# JB's Roast and Chops                                                       0.0
# Marketplace                                                                0.0
# McDonalds                                                                  0.0
# Other                                                                      0.0
# Panera                                                                     0.0
# Pitchforks                                                                 0.0
# Red Mango                                                                  0.0
# Saladelia at Perkins                                                       0.0
# Sazon                                                                      0.0
# Skillet                                                                    0.0
# Tandoor                                                                    0.0
# The Commons                                                                0.0
# Thyme                                                                      0.0
# Twinnie's                                                                  0.0
# Zweli's                                                                    0.0
#
# next                                    Devil's Krafthouse  \
# curr
# Cafe                                                  0.00
# Chef's Kitchen (Taste of San Fransico)                0.00
# Devil's Krafthouse                                    0.00
# Farmstead or Sprout                                   0.25
# Ginger and Soy                                        0.00
# Gothic Grill                                          0.00
# Il Forno                                              0.00
# JB's Roast and Chops                                  0.00
# Marketplace                                           0.50
# McDonalds                                             0.00
# Other                                                 0.00
# Panera                                                0.00
# Pitchforks                                            0.00
# Red Mango                                             0.00
# Saladelia at Perkins                                  0.00
# Sazon                                                 0.00
# Skillet                                               0.00
# Tandoor                                               0.00
# The Commons                                           0.00
# Thyme                                                 0.00
# Twinnie's                                             0.00
# Zweli's                                               0.20
#
# next                                    Farmstead or Sprout  Ginger and Soy  \
# curr
# Cafe                                                   0.00        0.000000
# Chef's Kitchen (Taste of San Fransico)                 0.00        0.666667
# Devil's Krafthouse                                     0.00        0.000000
# Farmstead or Sprout                                    0.00        0.000000
# Ginger and Soy                                         0.25        0.375000
# Gothic Grill                                           0.25        0.250000
# Il Forno                                               0.00        0.250000
# JB's Roast and Chops                                   0.00        0.500000
# Marketplace                                            0.00        0.000000
# McDonalds                                              0.00        0.000000
# Other                                                  0.00        0.100000
# Panera                                                 0.00        0.333333
# Pitchforks                                             0.00        0.750000
# Red Mango                                              0.00        0.000000
# Saladelia at Perkins                                   0.00        1.000000
# Sazon                                                  0.00        0.222222
# Skillet                                                0.00        0.333333
# Tandoor                                                0.00        0.222222
# The Commons                                            0.00        0.000000
# Thyme                                                  0.25        0.000000
# Twinnie's                                              0.00        0.000000
# Zweli's                                                0.00        0.000000
#
# next                                    Gothic Grill  Il Forno  \
# curr
# Cafe                                        0.000000  0.000000
# Chef's Kitchen (Taste of San Fransico)      0.000000  0.000000
# Devil's Krafthouse                          0.000000  0.000000
# Farmstead or Sprout                         0.250000  0.000000
# Ginger and Soy                              0.125000  0.000000
# Gothic Grill                                0.000000  0.000000
# Il Forno                                    0.000000  0.000000
# JB's Roast and Chops                        0.000000  0.250000
# Marketplace                                 0.000000  0.000000
# McDonalds                                   0.000000  1.000000
# Other                                       0.000000  0.100000
# Panera                                      0.000000  0.000000
# Pitchforks                                  0.000000  0.000000
# Red Mango                                   0.000000  0.000000
# Saladelia at Perkins                        0.000000  0.000000
# Sazon                                       0.000000  0.222222
# Skillet                                     0.000000  0.000000
# Tandoor                                     0.111111  0.222222
# The Commons                                 0.000000  0.000000
# Thyme                                       0.250000  0.000000
# Twinnie's                                   0.000000  0.000000
# Zweli's                                     0.000000  0.000000
#
# next                                    JB's Roast and Chops  Marketplace  \
# curr
# Cafe                                                0.000000     0.000000
# Chef's Kitchen (Taste of San Fransico)              0.000000     0.000000
# Devil's Krafthouse                                  0.000000     0.000000
# Farmstead or Sprout                                 0.250000     0.000000
# Ginger and Soy                                      0.000000     0.000000
# Gothic Grill                                        0.000000     0.000000
# Il Forno                                            0.125000     0.000000
# JB's Roast and Chops                                0.000000     0.000000
# Marketplace                                         0.000000     0.500000
# McDonalds                                           0.000000     0.000000
# Other                                               0.100000     0.000000
# Panera                                              0.000000     0.000000
# Pitchforks                                          0.000000     0.000000
# Red Mango                                           0.000000     0.000000
# Saladelia at Perkins                                0.000000     0.000000
# Sazon                                               0.222222     0.111111
# Skillet                                             0.000000     0.333333
# Tandoor                                             0.000000     0.000000
# The Commons                                         0.000000     0.000000
# Thyme                                               0.000000     0.000000
# Twinnie's                                           0.000000     0.000000
# Zweli's                                             0.000000     0.200000
#
# next                                    McDonalds  Nasher Cafe  Other  \
# curr
# Cafe                                        0.000          0.0  0.000
# Chef's Kitchen (Taste of San Fransico)      0.000          0.0  0.000
# Devil's Krafthouse                          0.000          0.0  0.000
# Farmstead or Sprout                         0.000          0.0  0.000
# Ginger and Soy                              0.125          0.0  0.125
# Gothic Grill                                0.000          0.0  0.000
# Il Forno                                    0.000          0.0  0.125
# JB's Roast and Chops                        0.000          0.0  0.250
# Marketplace                                 0.000          0.0  0.000
# McDonalds                                   0.000          0.0  0.000
# Other                                       0.000          0.1  0.400
# Panera                                      0.000          0.0  0.000
# Pitchforks                                  0.000          0.0  0.250
# Red Mango                                   0.000          0.0  0.500
# Saladelia at Perkins                        0.000          0.0  0.000
# Sazon                                       0.000          0.0  0.000
# Skillet                                     0.000          0.0  0.000
# Tandoor                                     0.000          0.0  0.000
# The Commons                                 0.000          0.0  0.000
# Thyme                                       0.000          0.0  0.000
# Twinnie's                                   0.000          0.0  0.000
# Zweli's                                     0.000          0.0  0.000
#
# next                                      Panera  Pitchforks  Red Mango  \
# curr
# Cafe                                    0.000000         0.0       0.00
# Chef's Kitchen (Taste of San Fransico)  0.000000         0.0       0.00
# Devil's Krafthouse                      0.500000         0.0       0.00
# Farmstead or Sprout                     0.000000         0.0       0.00
# Ginger and Soy                          0.000000         0.0       0.00
# Gothic Grill                            0.000000         0.0       0.25
# Il Forno                                0.000000         0.0       0.00
# JB's Roast and Chops                    0.000000         0.0       0.00
# Marketplace                             0.000000         0.0       0.00
# McDonalds                               0.000000         0.0       0.00
# Other                                   0.000000         0.1       0.00
# Panera                                  0.333333         0.0       0.00
# Pitchforks                              0.000000         0.0       0.00
# Red Mango                               0.000000         0.0       0.00
# Saladelia at Perkins                    0.000000         0.0       0.00
# Sazon                                   0.000000         0.0       0.00
# Skillet                                 0.000000         0.0       0.00
# Tandoor                                 0.111111         0.0       0.00
# The Commons                             0.000000         0.0       0.00
# Thyme                                   0.000000         0.0       0.00
# Twinnie's                               0.000000         0.0       1.00
# Zweli's                                 0.000000         0.0       0.00
#
# next                                       Sazon   Skillet   Tandoor  \
# curr
# Cafe                                    0.000000  0.000000  0.000000
# Chef's Kitchen (Taste of San Fransico)  0.333333  0.000000  0.000000
# Devil's Krafthouse                      0.000000  0.000000  0.000000
# Farmstead or Sprout                     0.250000  0.000000  0.000000
# Ginger and Soy                          0.000000  0.000000  0.000000
# Gothic Grill                            0.000000  0.000000  0.000000
# Il Forno                                0.125000  0.000000  0.375000
# JB's Roast and Chops                    0.000000  0.000000  0.000000
# Marketplace                             0.000000  0.000000  0.000000
# McDonalds                               0.000000  0.000000  0.000000
# Other                                   0.000000  0.000000  0.100000
# Panera                                  0.000000  0.000000  0.000000
# Pitchforks                              0.000000  0.000000  0.000000
# Red Mango                               0.500000  0.000000  0.000000
# Saladelia at Perkins                    0.000000  0.000000  0.000000
# Sazon                                   0.111111  0.000000  0.111111
# Skillet                                 0.000000  0.333333  0.000000
# Tandoor                                 0.000000  0.000000  0.000000
# The Commons                             0.000000  0.000000  0.500000
# Thyme                                   0.000000  0.000000  0.500000
# Twinnie's                               0.000000  0.000000  0.000000
# Zweli's                                 0.000000  0.000000  0.400000
#
# next                                       Thyme  Twinnie's   Zweli's
# curr
# Cafe                                    0.000000        0.0  0.000000
# Chef's Kitchen (Taste of San Fransico)  0.000000        0.0  0.000000
# Devil's Krafthouse                      0.000000        0.0  0.000000
# Farmstead or Sprout                     0.000000        0.0  0.000000
# Ginger and Soy                          0.000000        0.0  0.000000
# Gothic Grill                            0.250000        0.0  0.000000
# Il Forno                                0.000000        0.0  0.000000
# JB's Roast and Chops                    0.000000        0.0  0.000000
# Marketplace                             0.000000        0.0  0.000000
# McDonalds                               0.000000        0.0  0.000000
# Other                                   0.000000        0.0  0.000000
# Panera                                  0.333333        0.0  0.000000
# Pitchforks                              0.000000        0.0  0.000000
# Red Mango                               0.000000        0.0  0.000000
# Saladelia at Perkins                    0.000000        0.0  0.000000
# Sazon                                   0.000000        0.0  0.000000
# Skillet                                 0.000000        0.0  0.000000
# Tandoor                                 0.222222        0.0  0.111111
# The Commons                             0.000000        0.5  0.000000
# Thyme                                   0.000000        0.0  0.000000
# Twinnie's                               0.000000        0.0  0.000000
# Zweli's                                 0.000000        0.0  0.200000

# %%
### save transition matrix as csv
t.to_csv("transition.csv")

# %%
### define functions

def predict_future_lunch(curr_lunch, num_steps, transition_matrix=t):
    # params = today's lunch, x days in the future
    # ret = most likely lunch in x days
    t = transition_matrix**num_steps
    return t.loc[curr_lunch].idxmax()

def find_prob_of_future_lunch(curr_lunch, next_lunch, num_steps, transition_matrix=t):
    # params = today's lunch, next lunch, x days in the future, transition matrix 
    # ret = prob of eating at next_lunch in x days 
    t = transition_matrix**num_steps
    curr_index = transition_matrix.index.get_loc(curr_lunch)
    next_index = transition_matrix.columns.get_loc(next_lunch)
    return t.iloc[curr_index, next_index]

# %%
### test functions 

print(predict_future_lunch('Sazon', 1, t))
print(find_prob_of_future_lunch("Tandoor", "Zweli's", 1, t))
# Out:
# Ginger and Soy
# 0.1111111111111111
